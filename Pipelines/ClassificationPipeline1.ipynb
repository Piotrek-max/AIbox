# %%
from box.scalers import RobustMinMaxScaler
from sklearn.preprocessing import StandardScaler
import numpy as np

# %%
A = np.random.randn(100)
A
# Out:
# array([ 0.75327984, -0.19559365, -0.97401336,  2.20657881, -1.98473759,
#        -0.60798116,  0.89551483, -0.31306932, -0.3203235 ,  1.11510386,
#        -1.43786659,  1.5278441 ,  0.90053523,  0.20933994, -1.77253999,
#        -0.23270742,  1.41731822, -0.80878974,  0.23684059, -1.82524581,
#        -0.32774929,  0.41072573, -1.21844853,  0.73889583, -0.29494077,
#        -0.01312522,  0.44452123,  0.13027445,  1.57712066,  0.18178566,
#         1.39138793,  0.9849412 ,  0.55964299,  1.15414591,  0.39148888,
#        -0.83622362, -0.95776488,  1.74486257,  0.84160341,  1.21770765,
#         0.3239982 ,  1.40014829, -1.62556032,  0.42703287,  0.46616595,
#        -0.21080878, -0.42638196,  1.05686112,  0.41150211, -1.17479856,
#         0.67114662,  1.94958045, -1.26494633,  0.44958207,  1.25146608,
#        -0.09384178, -0.40956349,  1.29975605, -1.54133965, -1.02848283,
#        -1.9168679 ,  1.33955569, -1.45077485, -0.0431715 , -0.17965529,
# ...

# %%
scaler = RobustMinMaxScaler()
scaler.fit(A)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 2
#       1 scaler = RobustMinMaxScaler()
# ----> 2 scaler.fit(A)
#
# File ~\Codebase-projects\AIbox\box\scalers.py:14, in RobustMinMaxScaler.fit(self, X, y)
#      12 def fit(self, X, y=None):
# ---> 14     validate_data(
#      15         self,
#      16         X,
#      17         dtype=FLOAT_DTYPES,
#      18         ensure_all_finite="allow-nan"
#      19     )
#      20     q_min, q_max = self.quantile_range
#      21     if q_max > q_min:
#
# File ~\Codebase-projects\AIbox\.venv\Lib\site-packages\sklearn\utils\validation.py:2954, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2952         out = X, y
#    2953 elif not no_val_X and no_val_y:
# -> 2954     out = check_array(X, input_name="X", **check_params)
#    2955 elif no_val_X and not no_val_y:
# ...

# %%
scaler.transform(A)
# Out:
# array([-1.8998056 ,  1.67706297, -0.14685868,  0.28615753, -0.7846013 ,
#        -0.25707307, -1.25239062,  0.32630957, -0.66030274,  0.82063659,
#        -0.66579298,  0.15049317, -0.82334409,  0.69015216, -0.70133109,
#         0.4839431 , -1.30757412,  1.71184392, -0.23687757, -0.72457404,
#         1.39303799, -2.07803938,  0.80348496,  0.61955587, -1.82951941,
#        -0.14853074,  0.28407629, -1.07298234,  0.85794346, -0.88190547,
#        -2.01371829, -1.77083594,  0.60596433,  0.19401312, -0.09990791,
#        -0.97412569, -1.22427353,  0.53905206, -1.01014142,  0.38823709,
#         0.77475096, -0.63541617, -0.35981844, -0.23552747, -0.19555481,
#        -2.01718596, -0.608606  , -0.79935262, -0.87281306, -0.76916443,
#         0.56602399,  0.3111973 , -0.03079832, -0.88577831, -0.15106808,
#        -1.14318748, -0.30429394, -0.22846507,  1.20866328, -2.96538086,
#        -0.4132032 , -0.61525281, -1.13609635,  0.77056792, -1.62931962,
# ...
